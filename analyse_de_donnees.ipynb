# %% [markdown]
# # Spartial data

# %%
import rasterio
import matplotlib.pyplot as plt

# Open GeoTIFF
with rasterio.open("./ben_pop_2024_CN_1km_R2025A_UA_v1.tif") as src:
    img = src.read(1)  # read first band

# Plot
plt.imshow(img, cmap="viridis")
plt.colorbar(label="Pixel values")
plt.title("GeoTIFF - Band 1")
plt.show()
