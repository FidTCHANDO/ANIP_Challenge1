# %% [markdown]
# # Collecte des données

# %% [markdown]
# * Démographiques
#
# https://hub.worldpop.org/project/categories?id=3
#
# https://population.un.org/wpp/downloads?folder=Standard%20Projections&group=Most%20used
#
# https://dhsprogram.com/data/available-datasets.cfm
#
# * Économiques
#
# https://data.imf.org/en/Datasets#t=coveo117bcfc4&sort=%40idata_publication_date%20descending
#
# https://www.oecd.org/en/data.html
#
# https://unctadstat.unctad.org/EN/
#
# * Sociales
#
# https://www.who.int/data/gho
#
# https://hdr.undp.org/data-center
#
# https://genderdata.worldbank.org/en/home

# %%
import pandas as pd
import re

# %% [markdown]
# ## Données démographiques et sanitaires

# %%
dem = pd.read_excel("./WPP2024_GEN_F01_DEMOGRAPHIC_INDICATORS_COMPACT.xlsx", 
                    sheet_name="Estimates", skiprows=16, index_col="Index")

# %% [markdown]
# Extraire les données du BENIN

# %%
def get_one_value_var(database):
    entete = database.columns
    one_val_var = []
    for col in entete:
        if len(database[col].value_counts()) == 1 or database[col].isna().sum() == len(database):
            one_val_var.append(col)
    return one_val_var

def extract_region_data(dataset, region: str):
    extrated_df = dataset[dataset['Region, subregion, country or area *'] == region]
    extrated_df = extrated_df.drop(get_one_value_var(extrated_df), axis = 1)
    return extrated_df

# %%
benin_data = extract_region_data(dem, "Benin")

# %% [markdown]
# Véririfer qu'il n'y a pas de données manquantes

# %%
benin_data.isna().sum().sort_values(ascending=False)
# Out:
# Year                                                                                              0
# Total Population, as of 1 January (thousands)                                                     0
# Total Population, as of 1 July (thousands)                                                        0
# Male Population, as of 1 July (thousands)                                                         0
# Female Population, as of 1 July (thousands)                                                       0
# Population Density, as of 1 July (persons per square km)                                          0
# Population Sex Ratio, as of 1 July (males per 100 females)                                        0
# Median Age, as of 1 July (years)                                                                  0
# Natural Change, Births minus Deaths (thousands)                                                   0
# Rate of Natural Change (per 1,000 population)                                                     0
# Population Change (thousands)                                                                     0
# Population Growth Rate (percentage)                                                               0
# Population Annual Doubling Time (years)                                                           0
# Births (thousands)                                                                                0
# Births by women aged 15 to 19 (thousands)                                                         0
# Crude Birth Rate (births per 1,000 population)                                                    0
# Total Fertility Rate (live births per woman)                                                      0
# Net Reproduction Rate (surviving daughters per woman)                                             0
# Mean Age Childbearing (years)                                                                     0
# Sex Ratio at Birth (males per 100 female births)                                                  0
# Total Deaths (thousands)                                                                          0
# Male Deaths (thousands)                                                                           0
# Female Deaths (thousands)                                                                         0
# Crude Death Rate (deaths per 1,000 population)                                                    0
# Life Expectancy at Birth, both sexes (years)                                                      0
# Male Life Expectancy at Birth (years)                                                             0
# Female Life Expectancy at Birth (years)                                                           0
# Life Expectancy at Age 15, both sexes (years)                                                     0
# Male Life Expectancy at Age 15 (years)                                                            0
# Female Life Expectancy at Age 15 (years)                                                          0
# Life Expectancy at Age 65, both sexes (years)                                                     0
# Male Life Expectancy at Age 65 (years)                                                            0
# Female Life Expectancy at Age 65 (years)                                                          0
# Life Expectancy at Age 80, both sexes (years)                                                     0
# Male Life Expectancy at Age 80 (years)                                                            0
# Female Life Expectancy at Age 80 (years)                                                          0
# Infant Deaths, under age 1 (thousands)                                                            0
# Infant Mortality Rate (infant deaths per 1,000 live births)                                       0
# Live Births Surviving to Age 1 (thousands)                                                        0
# Under-Five Deaths, under age 5 (thousands)                                                        0
# Under-Five Mortality (deaths under age 5 per 1,000 live births)                                   0
# Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births)                   0
# Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births)                     0
# Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births)                 0
# Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births)                   0
# Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births)                     0
# Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births)                 0
# Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15)       0
# Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15)        0
# Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15)    0
# Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15)       0
# Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15)        0
# Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15)    0
# Net Number of Migrants (thousands)                                                                0
# Net Migration Rate (per 1,000 population)                                                         0
# dtype: int64

# %%
benin_data.sample(5)
# Out:
#          Year Total Population, as of 1 January (thousands)  \
# Index
# 5960   1985.0                                      4470.678
# 5926   1951.0                                      2258.543
# 5936   1961.0                                      2537.201
# 5951   1976.0                                      3487.775
# 5969   1994.0                                      6040.743
#
#       Total Population, as of 1 July (thousands)  \
# Index
# 5960                                    4538.012
# 5926                                    2267.308
# 5936                                    2559.223
# 5951                                    3532.196
# 5969                                    6096.506
#
#       Male Population, as of 1 July (thousands)  \
# Index
# 5960                                   2212.187
# 5926                                   1063.923
# 5936                                   1213.677
# 5951                                   1707.453
# 5969                                   2995.311
#
#       Female Population, as of 1 July (thousands)  \
# Index
# 5960                                     2325.825
# 5926                                     1203.385
# 5936                                     1345.546
# 5951                                     1824.744
# 5969                                     3101.195
#
#       Population Density, as of 1 July (persons per square km)  \
# Index
# 5960                                              40.245
# 5926                                              20.107
# 5936                                              22.696
# 5951                                              31.325
# 5969                                              54.066
#
#       Population Sex Ratio, as of 1 July (males per 100 females)  \
# Index
# 5960                                              95.114
# 5926                                              88.411
# 5936                                                90.2
# 5951                                              93.572
# 5969                                              96.586
#
#       Median Age, as of 1 July (years)  \
# Index
# 5960                            15.919
# 5926                            22.485
# 5936                            19.524
# 5951                            16.546
# 5969                            16.077
#
#       Natural Change, Births minus Deaths (thousands)  \
# Index
# 5960                                          136.623
# 5926                                           22.133
# 5936                                           48.835
# 5951                                           93.141
# 5969                                          196.639
#
#       Rate of Natural Change (per 1,000 population)  ...  \
# Index                                                ...
# 5960                                         30.106  ...
# 5926                                          9.762  ...
# 5936                                         19.083  ...
# 5951                                         26.369  ...
# 5969                                         32.254  ...
#
#       Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births)  \
# Index
# 5960                                             541.427
# 5926                                             708.472
# 5936                                              668.63
# 5951                                             585.101
# 5969                                             455.391
#
#       Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births)  \
# Index
# 5960                                             437.797
# 5926                                             646.245
# 5936                                              597.69
# 5951                                             503.829
# 5969                                              373.69
#
#       Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15)  \
# Index
# 5960                                             220.168
# 5926                                             319.322
# 5936                                              294.38
# 5951                                             247.315
# 5969                                             177.237
#
#       Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15)  \
# Index
# 5960                                             259.894
# 5926                                             345.753
# 5936                                             323.899
# 5951                                             279.086
# 5969                                             204.827
#
#       Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15)  \
# Index
# 5960                                             182.663
# 5926                                              294.53
# 5936                                             267.583
# 5951                                             218.294
# 5969                                             150.411
#
#       Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15)  \
# Index
# 5960                                             334.993
# 5926                                             458.605
# 5936                                             428.947
# 5951                                             369.297
# 5969                                             280.035
#
#       Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15)  \
# Index
# 5960                                             391.476
# 5926                                             498.358
# 5936                                             471.887
# 5951                                             415.556
# 5969                                             322.134
#
#       Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15)  \
# Index
# 5960                                             282.796
# 5926                                             421.837
# 5936                                             388.754
# 5951                                             327.199
# 5969                                             241.191
#
#       Net Number of Migrants (thousands)  \
# Index
# 5960                              -1.953
# 5926                              -4.602
# 5936                              -4.791
# 5951                              -4.308
# 5969                             -85.128
#
#       Net Migration Rate (per 1,000 population)
# Index
# 5960                                      -0.43
# 5926                                      -2.03
# 5936                                     -1.872
# 5951                                      -1.22
# 5969                                    -13.963
#
# [5 rows x 55 columns]

# %%
selected_cols = ['Year', 'Total Population, as of 1 July (thousands)',
       'Male Population, as of 1 July (thousands)',
       'Female Population, as of 1 July (thousands)','Births (thousands)',
       'Total Deaths (thousands)', 
       'Life Expectancy at Birth, both sexes (years)',
       'Net Number of Migrants (thousands)',
       'Net Migration Rate (per 1,000 population)']

# %% [markdown]
# ## Données démographique par âge

# %%
dem_age = pd.read_excel("./WPP_POP_5-YEAR_AGE_GROUPS.xlsx", sheet_name="Estimates", skiprows=16, index_col="Index")

# %%
benin_age = extract_region_data(dem_age, "Benin")

# %%
benin_age.tail()
# Out:
#          Year        0-4       5-9      10-14      15-19      20-24  \
# Index
# 5994   2019.0  2092.3305  1807.271   1557.247  1327.1545  1151.6015
# 5995   2020.0   2116.112  1859.698  1599.0325  1365.8045   1177.034
# 5996   2021.0  2135.8595    1910.8   1640.477   1408.263  1206.1245
# 5997   2022.0   2154.968  1957.322  1683.2985   1453.222  1236.6395
# 5998   2023.0  2176.4425  1996.616  1730.4715  1496.5645  1269.0645
#
#            25-29     30-34     35-39     40-44  ...     55-59     60-64  \
# Index                                           ...
# 5994     980.569   832.724  693.7485   553.619  ...  294.6915  217.8055
# 5995   1013.8375  856.8085  718.8575  574.4505  ...   306.682   226.844
# 5996    1043.758   881.233   742.482  597.6365  ...  317.9935  236.4485
# 5997    1073.106   905.375   765.456  622.3625  ...  328.8635  246.8635
# 5998    1102.765  929.7095   788.971   647.879  ...   339.823   257.763
#
#           65-69     70-74    75-79    80-84    85-89   90-94   95-99    100+
# Index
# 5994   156.9945  111.1135   68.977   33.205   12.255   3.018   0.439   0.035
# 5995    162.393  113.1305   71.357  34.4405   12.509   3.032   0.433  0.0335
# 5996   168.0235   115.467   73.373  35.6995   12.699   3.005   0.414  0.0305
# 5997   174.3795   118.432  75.0465  37.0095  13.0405  3.0435  0.4085   0.029
# 5998   181.4615  121.8785  76.7765   38.473   13.547   3.148   0.418  0.0295
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Données Finances

# %%
benin_finance = pd.read_csv('./INTEGRATION_IMF.STA_ANEA_BENIN.csv')

# %%
benin_finance.head()
# Out:
#   COUNTRY         INDICATOR       PRICE_TYPE TYPE_OF_TRANSFORMATION FREQUENCY  \
# 0   Benin  Exports of goods  Constant prices      Domestic currency    Annual
# 1   Benin  Exports of goods  Constant prices      Domestic currency    Annual
# 2   Benin  Exports of goods  Constant prices      Domestic currency    Annual
# 3   Benin  Exports of goods  Constant prices      Domestic currency    Annual
# 4   Benin  Exports of goods  Constant prices      Domestic currency    Annual
#
#    TIME_PERIOD     OBS_VALUE  SCALE
# 0       1999.0  6.090000e+11    NaN
# 1       2000.0  5.800000e+11    NaN
# 2       2001.0  6.070000e+11    NaN
# 3       2002.0  6.850000e+11    NaN
# 4       2003.0  7.080000e+11    NaN

# %%
benin_finance = benin_finance[(benin_finance["COUNTRY"] == "Benin")]

# %%
benin_gdp = benin_finance[(benin_finance['INDICATOR'] == "Gross domestic product (GDP)") &
                          (benin_finance["TYPE_OF_TRANSFORMATION"] == "Domestic currency") &
                          (benin_finance["PRICE_TYPE"] == "Constant prices")][["TIME_PERIOD",
                                                                               "OBS_VALUE"]]

# %%
# benin_gdp.rename(columns={"TIME_PERIOD": "Year", "OBS_VALUE": "GDP"})
benin_gdp.columns = ["Year", "GDP_ConstantPrice"]
benin_gdp["Year"] = benin_gdp["Year"].astype(int)
benin_gdp = benin_gdp.dropna()
benin_gdp.dtypes
# Out:
# Year    float64
# GDP     float64
# dtype: object

# %% [markdown]
# ## Fusion des trois tables de données

# %%
print(benin_data.shape)
print(benin_age.shape)
print(benin_gdp.shape)
# Out:
# (74, 55)
# (74, 22)
# (43, 2)

# %% [markdown]
# Fusion en utilisant l'année

# %%
benin_df = benin_data[selected_cols].merge(benin_gdp,
                                           how="inner", on="Year").merge(benin_age, 
                                                                         how="inner", 
                                                                         on="Year")
# benin_df.reset_index(drop=True)
benin_df.head()
# Out:
#      Year Total Population, as of 1 July (thousands)  \
# 0  1962.0                                   2604.659
# 1  1963.0                                   2652.908
# 2  1964.0                                   2704.003
# 3  1965.0                                   2757.936
# 4  1966.0                                   2814.317
#
#   Male Population, as of 1 July (thousands)  \
# 0                                  1236.778
# 1                                  1261.327
# 2                                  1287.274
# 3                                  1314.605
# 4                                  1343.249
#
#   Female Population, as of 1 July (thousands) Births (thousands)  \
# 0                                     1367.88            122.713
# 1                                    1391.581            125.726
# 2                                    1416.729            128.765
# 3                                    1443.331            131.635
# 4                                    1471.068            134.106
#
#   Total Deaths (thousands) Life Expectancy at Birth, both sexes (years)  \
# 0                   71.049                                       39.643
# 1                   71.212                                       40.081
# 2                   71.412                                       40.502
# 3                   71.482                                       40.971
# 4                   71.937                                       41.274
#
#   Net Number of Migrants (thousands)  \
# 0                             -4.844
# 1                             -4.847
# 2                             -4.839
# 3                             -4.793
# 4                             -4.764
#
#   Net Migration Rate (per 1,000 population)           GDP  ...    55-59  \
# 0                                     -1.86  9.910000e+11  ...  90.1305
# 1                                    -1.827  1.110000e+12  ...   90.476
# 2                                     -1.79  1.190000e+12  ...   90.748
# 3                                    -1.738  1.250000e+12  ...    90.93
# 4                                    -1.693  1.300000e+12  ...    91.02
#
#      60-64    65-69    70-74    75-79    80-84  85-89   90-94   95-99    100+
# 0  76.8475  61.0445  42.9375  26.3465  13.3635  5.447  1.1555   0.061       0
# 1  77.0095   61.399   43.262    26.23   13.137  5.138  1.2165    0.07       0
# 2  77.2175  61.7405   43.626   26.222  12.9765  4.896  1.2305    0.08  0.0005
# 3   77.481   62.072   44.001  26.3165   12.869  4.731   1.205  0.0925   0.001
# 4  77.7915  62.3705  44.3805  26.4865   12.805  4.615   1.159   0.105  0.0005
#
# [5 rows x 31 columns]

# %%
benin_df.shape
# Out:
# (43, 10)

# %%
benin_df['ID'] = benin_df.index

benin_df = benin_df[[benin_df.columns[-1]] + list(benin_df.columns[:-1])]

# %% [markdown]
# Exporter les données en parquet ou Excel

# %%
benin_df["Population 0-14"] = benin_df[benin_df.columns[11:14]].sum(axis=1)
benin_df["Population 15-59"] = benin_df[benin_df.columns[14:23]].sum(axis=1)
benin_df["Population 60+"] = benin_df[benin_df.columns[23:32]].sum(axis=1)

benin_df = benin_df.drop(benin_df.columns[11:32], axis=1)

# %%
benin_df.sample()

# %%
benin_df = benin_df.rename(columns={'Year': 'Année', 
                         'Total Population, as of 1 July (thousands)': 'Population 1er Juin',
                         'Male Population, as of 1 July (thousands)': 'Population Masculine 1er Juin',
                         'Female Population, as of 1 July (thousands)': 'Population Féminine 1er Juin', 
                         'Births (thousands)': 'Naissances', 'Total Deaths (thousands)': 'Décès',
                         'Life Expectancy at Birth, both sexes (years)': 'Espérance de vie à la naissance',
                         'Net Number of Migrants (thousands)': 'Solde migratoire',
                         'Net Migration Rate (per 1,000 population)': 'Taux de migration net'})

# %%
benin_df.to_excel("Donnees_ben_pop.xlsx", index=False)

# %% [markdown]
# Les 5 premieres lignes

# %%
benin_df[:5].to_parquet("Donnees_ben_pop.parquet", engine="pyarrow")

# %% [markdown]
# Glossaire des variables

# %%
glossaire = pd.DataFrame({
    'nom': benin_df.columns,

    'définitions': ['Identifiant', "L'année de la donnée", "Effectif de la population au 1er juin",
                    "Effectif des Hommes au 1er juin", "Effectif des Femmes au 1er juin", 
                    "Naissances total", "Décès total", "Expérience de vie à la naissances",
                    "Solde migratoire",  "Taux migratoire net", "Population 0 - 14 ans",
                    "Population 15 - 59 ans", "Population 60+"],

    'unité': ['nombre', "nombre d'année", "1000 habitants", "1000 habitants", "1000 habitants",
              "1000 naissances", "1000 décès", "nombre d'années", "1000 personnes", "1000 habitants",
              "habitant", "habitant", "habitant" ],

     'source' : ["https://population.un.org/wpp/downloads?folder=Standard%20Projections&group=Most%20used"]*13,
     
     'periode': [str(int(min(benin_df['Année']))) + ' - ' + str(int(max(benin_df['Année'])))]*13,
     
     'géographie': ["Benin"]*13})

# %%
glossaire.to_excel('Glossaire_des_variables.xlsx', index=False)
